# %% [raw]
# ---
# title: "Longterm Investment"
# description: " "
# author: "Benjamin DK Luong"
# date: "2023-01-10"
# categories: [Stock Market, Longterm, Investment]
# image: "../images/longterm.jpg"
# ---

# %%
#| column: screen-inset-shaded
#| echo: false
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from utils import longterm_investment as lt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

data = lt.get_longterm_investment()
data
# Out:
# 0  Ticker                  Sector Market Cap Dividend     ROA      ROE  \
# 0      CF         Basic Materials     16.16B    1.93%  24.10%   78.60%
# 1     MOS         Basic Materials     14.60B    1.78%  16.00%   32.70%
# 2    META  Communication Services    340.47B        -  17.00%   23.20%
# 3   GOOGL  Communication Services   1133.00B        -  18.70%   26.40%
# 4    ATVI  Communication Services     60.31B    0.60%   6.70%    9.20%
# 5      KO      Consumer Defensive    263.60B    2.83%  10.60%   42.40%
# 6    BF-B      Consumer Defensive     30.91B    1.26%  13.60%   31.90%
# 7    FANG                  Energy     24.24B    2.11%  17.60%   31.70%
# 8     DVN                  Energy     40.55B    8.19%  27.90%   63.30%
# 9     EOG                  Energy     73.14B    2.59%  19.30%   33.20%
# 10    PXD                  Energy     53.43B   11.27%  19.40%   30.50%
# 11    COP                  Energy    145.32B    4.40%  19.40%   37.30%
# ...
