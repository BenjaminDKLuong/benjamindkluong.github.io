# %% [raw]
# ---
# title: "Real Estate Investment"
# description: " "
# author: "Benjamin DK Luong"
# date: "2023-01-11"
# categories: [Stock Market, Investment]
# image: "../images/real_estate.jpg"
# ---

# %% [markdown]
# If you want to invest into real estate and dont have enough cash to buy a whole property, you can invest in Real Estate stocks. Here are a list of real estate stocks with good net profits. You should watch out for stocks with high Debt/Equity which means the companies have a lot of debt compare to their equities.
#
# <br>

# %%
#| echo: false
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from utils import real_estate as re

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

data = re.get_longterm_investment()
data.to_csv('data/real_estate.csv',index=False)

# %%
#| column: screen-inset-shaded
#| echo: false
data = pd.read_csv('data/real_estate.csv')
data
# Out:
# 0  Ticker       Sector Market Cap Dividend     ROA     ROE     ROI Curr R  \
# 0     PLD  Real Estate    103.63B    2.72%   6.70%  11.70%   2.50%      -
# 1     CPT  Real Estate     11.62B    3.32%   7.80%  14.80%   1.70%      -
# 2     EXR  Real Estate     19.21B    4.10%   8.40%  28.90%  10.50%      -
# 3     AVB  Real Estate     22.02B    3.90%   5.80%  10.50%   1.90%      -
# 4     EQR  Real Estate     21.50B    4.26%   5.50%  10.50%   8.60%      -
# 5     SPG  Real Estate     39.58B    6.16%   5.90%  62.70%   8.20%      -
# 6    VICI  Real Estate     31.96B    4.82%   2.80%   4.50%   8.30%      -
# 7     MAA  Real Estate     17.27B    3.62%   5.50%  10.40%   4.20%      -
# 8     DLR  Real Estate     28.46B    4.77%   3.80%   8.40%   2.00%      -
# 9     FRT  Real Estate      8.15B    4.24%   4.00%  12.20%   6.00%      -
# 10    BXP  Real Estate     10.11B    5.82%   3.80%  14.60%   4.90%      -
# 11   PEAK  Real Estate     13.65B    4.59%   3.60%   8.70%   0.70%      -
# 12    AMT  Real Estate    100.33B    2.81%   4.20%  49.00%   5.90%   0.60
# 13    CCI  Real Estate     61.53B    4.26%   4.10%  20.30%   6.40%   0.50
# 14     WY  Real Estate     21.77B    2.33%  13.10%  21.40%  18.50%   2.90
# 15      O  Real Estate     39.79B    4.65%   1.50%   2.50%   0.70%      -
#
# 0  Quick R Debt/Eq Gross M  Oper M Profit M
# 0        -    0.51  74.70%  38.80%   73.10%
# 1        -    0.73  62.60%  46.00%   50.80%
# 2        -    2.15  75.60%  59.20%   50.10%
# 3        -    0.72  64.30%  20.00%   45.80%
# 4        -    0.68  63.20%  56.50%   42.60%
# 5        -    8.27  80.70%  47.30%   37.70%
# 6        -    0.67  99.00%  54.50%   35.90%
# 7        -    0.75  60.50%  31.40%   32.00%
# 8        -    0.96  60.60%  12.00%   30.70%
# 9        -    1.59  66.80%  43.60%   29.80%
# 10       -    2.29  63.20%  34.50%   28.50%
# 11       -    1.02  58.40%  18.50%   27.80%
# 12    0.60    6.10  69.40%  26.50%   27.80%
# 13    0.50    2.80  69.90%  33.60%   23.50%
# 14    2.40    0.47  37.20%  30.10%   21.60%
# 15       -    0.61  93.60%  18.70%   20.60%
